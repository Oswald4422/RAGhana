# %% [markdown]
# # Notebook 01 – Data Exploration
# Inspect the raw CSV and PDF before any cleaning or chunking.

# %%
# %pip install -q pandas pypdf numpy sentence-transformers openai tiktoken python-dotenv scikit-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
#Load raw data from the Dataset/ folder.
import pandas as pd
import pypdf
from pathlib import Path

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'backend'))
from raghana.ingest import load_csv, load_pdf

raw_df = load_csv()
print('CSV shape:', raw_df.shape)
print('Columns:', list(raw_df.columns))
raw_df.head(10)
# Out:
# CSV shape: (615, 8)
# Columns: ['Year', 'Old Region', 'New Region', 'Code', 'Candidate', 'Party', 'Votes', 'Votes(%)']
#    Year          Old Region    New Region    Code  \
# 0  2020  Brong Ahafo Region  Ahafo Region     NPP
# 1  2020  Brong Ahafo Region  Ahafo Region     NDC
# 2  2020  Brong Ahafo Region  Ahafo Region  Others
# 3  2020  Brong Ahafo Region  Ahafo Region  Others
# 4  2020  Brong Ahafo Region  Ahafo Region  Others
# 5  2020  Brong Ahafo Region  Ahafo Region  Others
# 6  2020  Brong Ahafo Region  Ahafo Region  Others
# 7  2020  Brong Ahafo Region  Ahafo Region  Others
# 8  2020  Brong Ahafo Region  Ahafo Region  Others
# 9  2020  Brong Ahafo Region  Ahafo Region  Others
#
#                         Candidate Party   Votes Votes(%)
# 0                 Nana Akufo Addo   NPP  145584   55.04%
# 1             John Dramani Mahama   NDC  116485   44.04%
# 2         Ivor Kobina Greenstreet   CPP     191    0.07%
# 3  David Asibi Ayindenaba Apasera   PNC      83    0.03%
# ...

# %%
# Unique years and regions
print('Years:', sorted(raw_df['Year'].unique()))
if 'New Region' in raw_df.columns:
    print('New Regions:', sorted(raw_df['New Region'].dropna().unique()))
# Out:
# Years: [1992, 1996, 2000, 2004, 2008, 2012, 2016, 2020]
# New Regions: ['Ahafo\xa0Region', 'Ashanti Region', 'Ashanti\xa0Region', 'Bono East\xa0Region', 'Bono\xa0Region', 'Brong Ahafo Region', 'Brong Ahafo\xa0Region', 'Central Region', 'Central\xa0Region', 'Eastern Region', 'Eastern\xa0Region', 'Greater Accra Region', 'Greater Accra\xa0Region', 'North East\xa0Region', 'Northern Region', 'Northern\xa0Region', 'Oti\xa0Region', 'Savannah\xa0Region', 'Upper East Region', 'Upper East\xa0Region', 'Upper West Region', 'Upper West\xa0Region', 'Volta Region', 'Volta\xa0Region', 'Western North\xa0Region', 'Western Region', 'Western\xa0Region']

# %%
# Candidates per year
raw_df.groupby('Year')['Candidate'].nunique()
# Out:
# Year
# 1992     3
# 1996     3
# 2000     5
# 2004     4
# 2008     5
# 2012     7
# 2016     7
# 2020    12
# Name: Candidate, dtype: int64

# %%
# PDF: page count and first page preview
pages = load_pdf()
print(f'Total pages: {len(pages)}')
print('\n--- Page 1 preview ---')
print(pages[0]['text'][:800])
# Out:
# Total pages: 252
#
# --- Page 1 preview ---
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# THEME:  Resetting The Economy For The Ghana We Want

# %%
# Check for encoding issues in CSV
print('Raw first column name repr:', repr(list(raw_df.columns)[0]))
print('Null counts per column:')
print(raw_df.isnull().sum())
# Out:
# Raw first column name repr: 'Year'
# Null counts per column:
# Year          0
# Old Region    0
# New Region    0
# Code          0
# Candidate     0
# Party         0
# Votes         0
# Votes(%)      0
# dtype: int64
